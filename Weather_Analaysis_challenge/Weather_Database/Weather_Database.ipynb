# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        crnt_description = city_weather['weather'][0]['description']
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                  "Lat": city_lat,
                  "Lng": city_lng,
                  "Max Temp": city_max_temp,
                  "Humidity": city_humidity,
                  "Current Discription": crnt_description,
                  "Cloudiness": city_clouds,
                  "Wind Speed": city_wind,
                  "Country": city_country})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | hasaki
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | college
# Processing Record 9 of Set 1 | komsomolskiy
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | asyut
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | kloulklubed
# Processing Record 21 of Set 1 | sao filipe
# Processing Record 22 of Set 1 | isangel
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | kayes
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | raga
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | husavik
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | brewster
# Processing Record 38 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 1 | biak
# Processing Record 40 of Set 1 | talaya
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | maniitsoq
# Processing Record 46 of Set 1 | doba
# Processing Record 47 of Set 1 | malakal
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | pemangkat
# Processing Record 50 of Set 1 | comodoro rivadavia
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | kidal
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | payakumbuh
# Processing Record 7 of Set 2 | salinopolis
# Processing Record 8 of Set 2 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 2 | corrente
# Processing Record 10 of Set 2 | zelenogradsk
# Processing Record 11 of Set 2 | vila franca do campo
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | hambantota
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | bolitoc
# Processing Record 16 of Set 2 | salisbury
# Processing Record 17 of Set 2 | daru
# Processing Record 18 of Set 2 | shitkino
# Processing Record 19 of Set 2 | darhan
# Processing Record 20 of Set 2 | sterling
# Processing Record 21 of Set 2 | cap malheureux
# Processing Record 22 of Set 2 | diffa
# Processing Record 23 of Set 2 | lodja
# Processing Record 24 of Set 2 | mahebourg
# Processing Record 25 of Set 2 | elk city
# Processing Record 26 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 2 | whyalla
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | shingu
# Processing Record 30 of Set 2 | cam ranh
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | ust-koksa
# Processing Record 33 of Set 2 | gizo
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | narrabri
# Processing Record 36 of Set 2 | conway
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | baykit
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | dwarka
# Processing Record 42 of Set 2 | san andres
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | baoning
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | fort frances
# Processing Record 47 of Set 2 | liverpool
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | saldanha
# Processing Record 50 of Set 2 | elat
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | ostrovnoy
# Processing Record 4 of Set 3 | bom jardim
# Processing Record 5 of Set 3 | maldonado
# Processing Record 6 of Set 3 | marion
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | wukari
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | pacific grove
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | magadan
# Processing Record 14 of Set 3 | georgetown
# Processing Record 15 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 3 | ampanihy
# Processing Record 17 of Set 3 | castanos
# Processing Record 18 of Set 3 | cumbum
# Processing Record 19 of Set 3 | mubende
# Processing Record 20 of Set 3 | solnechnyy
# Processing Record 21 of Set 3 | teacapan
# Processing Record 22 of Set 3 | srednekolymsk
# Processing Record 23 of Set 3 | kupang
# Processing Record 24 of Set 3 | fayaoue
# Processing Record 25 of Set 3 | saint george
# Processing Record 26 of Set 3 | jidong
# Processing Record 27 of Set 3 | shostka
# Processing Record 28 of Set 3 | tupelo
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | quatre cocos
# Processing Record 32 of Set 3 | alyangula
# Processing Record 33 of Set 3 | arrifes
# Processing Record 34 of Set 3 | dukat
# Processing Record 35 of Set 3 | sur
# Processing Record 36 of Set 3 | nanortalik
# Processing Record 37 of Set 3 | vila velha
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | isoka
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 3 | gamba
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | agogo
# Processing Record 45 of Set 3 | lichtenfels
# Processing Record 46 of Set 3 | cuiluan
# Processing Record 47 of Set 3 | te anau
# Processing Record 48 of Set 3 | lata
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | freeport
# Processing Record 2 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 4 | brae
# Processing Record 4 of Set 4 | ulaangom
# Processing Record 5 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 4 | atasu
# Processing Record 7 of Set 4 | mehamn
# Processing Record 8 of Set 4 | poum
# Processing Record 9 of Set 4 | kushima
# Processing Record 10 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 4 | port hardy
# Processing Record 12 of Set 4 | ahipara
# Processing Record 13 of Set 4 | zhezkazgan
# Processing Record 14 of Set 4 | galesburg
# Processing Record 15 of Set 4 | dakoro
# Processing Record 16 of Set 4 | mazatan
# Processing Record 17 of Set 4 | shaunavon
# Processing Record 18 of Set 4 | dekernes
# Processing Record 19 of Set 4 | bubaque
# Processing Record 20 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | kiama
# Processing Record 23 of Set 4 | kudahuvadhoo
# Processing Record 24 of Set 4 | anadyr
# Processing Record 25 of Set 4 | tasiilaq
# Processing Record 26 of Set 4 | moron
# Processing Record 27 of Set 4 | miles city
# Processing Record 28 of Set 4 | mastic beach
# Processing Record 29 of Set 4 | marawi
# Processing Record 30 of Set 4 | alihe
# Processing Record 31 of Set 4 | luzhou
# Processing Record 32 of Set 4 | kihei
# Processing Record 33 of Set 4 | caravelas
# Processing Record 34 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | ballina
# Processing Record 37 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 4 | bijapur
# Processing Record 39 of Set 4 | hofn
# Processing Record 40 of Set 4 | santa maria
# Processing Record 41 of Set 4 | butaritari
# Processing Record 42 of Set 4 | nikolskoye
# Processing Record 43 of Set 4 | xuddur
# Processing Record 44 of Set 4 | pindiga
# Processing Record 45 of Set 4 | sistranda
# Processing Record 46 of Set 4 | bagdarin
# Processing Record 47 of Set 4 | lukoyanov
# Processing Record 48 of Set 4 | marsaxlokk
# Processing Record 49 of Set 4 | sitka
# Processing Record 50 of Set 4 | challans
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | bosaso
# Processing Record 3 of Set 5 | newport
# Processing Record 4 of Set 5 | mayo
# Processing Record 5 of Set 5 | posadas
# Processing Record 6 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 5 | chapais
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | lavrentiya
# Processing Record 12 of Set 5 | ponta delgada
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | mujiayingzi
# Processing Record 15 of Set 5 | greaca
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | zyryanskoye
# Processing Record 18 of Set 5 | thinadhoo
# Processing Record 19 of Set 5 | jawhar
# Processing Record 20 of Set 5 | marzuq
# Processing Record 21 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 22 of Set 5 | rochegda
# Processing Record 23 of Set 5 | ola
# Processing Record 24 of Set 5 | isiro
# Processing Record 25 of Set 5 | namatanai
# Processing Record 26 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 5 | laguna
# Processing Record 28 of Set 5 | vardo
# Processing Record 29 of Set 5 | pizarro
# Processing Record 30 of Set 5 | halifax
# Processing Record 31 of Set 5 | bathsheba
# Processing Record 32 of Set 5 | tongliao
# Processing Record 33 of Set 5 | bredasdorp
# Processing Record 34 of Set 5 | bahile
# Processing Record 35 of Set 5 | stornoway
# Processing Record 36 of Set 5 | yulara
# Processing Record 37 of Set 5 | jalu
# Processing Record 38 of Set 5 | minab
# Processing Record 39 of Set 5 | tumut
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | upata
# Processing Record 42 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 5 | ajdabiya
# Processing Record 44 of Set 5 | beloha
# Processing Record 45 of Set 5 | taoudenni
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | cocobeach
# Processing Record 48 of Set 5 | lorengau
# Processing Record 49 of Set 5 | guanica
# Processing Record 50 of Set 5 | peoria
# Processing Record 1 of Set 6 | casino
# Processing Record 2 of Set 6 | ust-omchug
# Processing Record 3 of Set 6 | pombas
# Processing Record 4 of Set 6 | havelock
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | seoul
# Processing Record 8 of Set 6 | dingle
# Processing Record 9 of Set 6 | loudi
# Processing Record 10 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 6 | mbandaka
# Processing Record 13 of Set 6 | clyde river
# Processing Record 14 of Set 6 | kenai
# Processing Record 15 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 6 | khatanga
# Processing Record 17 of Set 6 | ahuimanu
# Processing Record 18 of Set 6 | ouesso
# Processing Record 19 of Set 6 | ust-nera
# Processing Record 20 of Set 6 | erzin
# Processing Record 21 of Set 6 | kavieng
# Processing Record 22 of Set 6 | kodiak
# Processing Record 23 of Set 6 | neepawa
# Processing Record 24 of Set 6 | kalmunai
# Processing Record 25 of Set 6 | ostrow mazowiecka
# Processing Record 26 of Set 6 | beringovskiy
# Processing Record 27 of Set 6 | faya
# Processing Record 28 of Set 6 | rusape
# Processing Record 29 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | san francisco
# Processing Record 31 of Set 6 | bilibino
# Processing Record 32 of Set 6 | akonolinga
# Processing Record 33 of Set 6 | katsuura
# Processing Record 34 of Set 6 | cidreira
# Processing Record 35 of Set 6 | sovetskiy
# Processing Record 36 of Set 6 | severnyy
# Processing Record 37 of Set 6 | coihaique
# Processing Record 38 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 6 | emerald
# Processing Record 40 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 6 | piterka
# Processing Record 42 of Set 6 | bitung
# Processing Record 43 of Set 6 | yebaishou
# Processing Record 44 of Set 6 | adre
# Processing Record 45 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 6 | hun
# Processing Record 47 of Set 6 | west fargo
# Processing Record 48 of Set 6 | eregli
# Processing Record 49 of Set 6 | noumea
# Processing Record 50 of Set 6 | ilulissat
# Processing Record 1 of Set 7 | palu
# Processing Record 2 of Set 7 | bengkulu
# Processing Record 3 of Set 7 | grootfontein
# Processing Record 4 of Set 7 | huinan
# Processing Record 5 of Set 7 | ratnagiri
# Processing Record 6 of Set 7 | luena
# Processing Record 7 of Set 7 | fegyvernek
# Processing Record 8 of Set 7 | fairbanks
# Processing Record 9 of Set 7 | bahia blanca
# Processing Record 10 of Set 7 | pringsewu
# Processing Record 11 of Set 7 | ndola
# Processing Record 12 of Set 7 | paita
# Processing Record 13 of Set 7 | sri aman
# Processing Record 14 of Set 7 | sibu
# Processing Record 15 of Set 7 | ribeira grande
# Processing Record 16 of Set 7 | gilbues
# Processing Record 17 of Set 7 | gouyave
# Processing Record 18 of Set 7 | guerrero negro
# Processing Record 19 of Set 7 | tual
# Processing Record 20 of Set 7 | buala
# Processing Record 21 of Set 7 | neyvo-shaytanskiy
# Processing Record 22 of Set 7 | portland
# Processing Record 23 of Set 7 | half moon bay
# Processing Record 24 of Set 7 | floriano
# Processing Record 25 of Set 7 | kondinskoye
# Processing Record 26 of Set 7 | alice springs
# Processing Record 27 of Set 7 | gwanda
# Processing Record 28 of Set 7 | olavarria
# Processing Record 29 of Set 7 | chapadinha
# Processing Record 30 of Set 7 | lagos
# Processing Record 31 of Set 7 | magdug
# Processing Record 32 of Set 7 | sakakah
# Processing Record 33 of Set 7 | berlevag
# Processing Record 34 of Set 7 | chichli
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | norman wells
# Processing Record 37 of Set 7 | flinders
# Processing Record 38 of Set 7 | waingapu
# Processing Record 39 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 7 | nelson bay
# Processing Record 41 of Set 7 | sabang
# Processing Record 42 of Set 7 | itarema
# Processing Record 43 of Set 7 | primero de enero
# Processing Record 44 of Set 7 | turukhansk
# Processing Record 45 of Set 7 | tias
# Processing Record 46 of Set 7 | razdolinsk
# Processing Record 47 of Set 7 | paamiut
# Processing Record 48 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 7 | vallenar
# Processing Record 50 of Set 7 | hualmay
# Processing Record 1 of Set 8 | montepuez
# Processing Record 2 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 8 | uribia
# Processing Record 4 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 8 | luderitz
# Processing Record 6 of Set 8 | shu
# Processing Record 7 of Set 8 | diamantino
# Processing Record 8 of Set 8 | touros
# Processing Record 9 of Set 8 | saskylakh
# Processing Record 10 of Set 8 | kyra
# Processing Record 11 of Set 8 | angoche
# Processing Record 12 of Set 8 | zyryanka
# Processing Record 13 of Set 8 | odesskoye
# Processing Record 14 of Set 8 | mao
# Processing Record 15 of Set 8 | yenagoa
# Processing Record 16 of Set 8 | huilong
# Processing Record 17 of Set 8 | mount isa
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | carutapera
# Processing Record 20 of Set 8 | pontiac
# Processing Record 21 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 8 | xiamen
# Processing Record 23 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 8 | necochea
# Processing Record 25 of Set 8 | qasigiannguit
# Processing Record 26 of Set 8 | zhuhai
# Processing Record 27 of Set 8 | camopi
# Processing Record 28 of Set 8 | chuka
# Processing Record 29 of Set 8 | torbay
# Processing Record 30 of Set 8 | sao joao da barra
# Processing Record 31 of Set 8 | nara
# Processing Record 32 of Set 8 | kutum
# Processing Record 33 of Set 8 | buchanan
# Processing Record 34 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 8 | baruun-urt
# Processing Record 36 of Set 8 | litovko
# Processing Record 37 of Set 8 | kapit
# Processing Record 38 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 8 | henties bay
# Processing Record 40 of Set 8 | opuwo
# Processing Record 41 of Set 8 | port blair
# Processing Record 42 of Set 8 | ridgecrest
# Processing Record 43 of Set 8 | sabya
# Processing Record 44 of Set 8 | pochutla
# Processing Record 45 of Set 8 | pundaguitan
# Processing Record 46 of Set 8 | ucluelet
# Processing Record 47 of Set 8 | oussouye
# Processing Record 48 of Set 8 | sola
# Processing Record 49 of Set 8 | pasni
# Processing Record 50 of Set 8 | haines junction
# Processing Record 1 of Set 9 | namibe
# Processing Record 2 of Set 9 | salta
# Processing Record 3 of Set 9 | gatton
# Processing Record 4 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 9 | manokwari
# Processing Record 6 of Set 9 | nouadhibou
# Processing Record 7 of Set 9 | deputatskiy
# Processing Record 8 of Set 9 | novyy svit
# Processing Record 9 of Set 9 | hamilton
# Processing Record 10 of Set 9 | goderich
# Processing Record 11 of Set 9 | kamenka
# Processing Record 12 of Set 9 | arlit
# Processing Record 13 of Set 9 | celestun
# Processing Record 14 of Set 9 | tharrawaddy
# City not found. Skipping...
# Processing Record 15 of Set 9 | canhotinho
# Processing Record 16 of Set 9 | qaqortoq
# Processing Record 17 of Set 9 | liminangcong
# City not found. Skipping...
# Processing Record 18 of Set 9 | presidencia roque saenz pena
# Processing Record 19 of Set 9 | yerbogachen
# Processing Record 20 of Set 9 | qandala
# Processing Record 21 of Set 9 | mufumbwe
# Processing Record 22 of Set 9 | baghdad
# Processing Record 23 of Set 9 | kearney
# Processing Record 24 of Set 9 | aksarka
# Processing Record 25 of Set 9 | tateyama
# Processing Record 26 of Set 9 | aasiaat
# Processing Record 27 of Set 9 | olafsvik
# Processing Record 28 of Set 9 | digby
# Processing Record 29 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 9 | constitucion
# Processing Record 31 of Set 9 | vangaindrano
# Processing Record 32 of Set 9 | shenzhen
# Processing Record 33 of Set 9 | anbu
# Processing Record 34 of Set 9 | auki
# Processing Record 35 of Set 9 | hayden
# Processing Record 36 of Set 9 | havre-saint-pierre
# Processing Record 37 of Set 9 | kirakira
# Processing Record 38 of Set 9 | greencastle
# Processing Record 39 of Set 9 | molokovo
# Processing Record 40 of Set 9 | batagay-alyta
# Processing Record 41 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 9 | dunedin
# Processing Record 43 of Set 9 | xichang
# Processing Record 44 of Set 9 | okhotsk
# Processing Record 45 of Set 9 | salalah
# Processing Record 46 of Set 9 | monrovia
# Processing Record 47 of Set 9 | udomlya
# Processing Record 48 of Set 9 | vanimo
# Processing Record 49 of Set 9 | pudozh
# Processing Record 50 of Set 9 | hinatuan
# Processing Record 1 of Set 10 | asau
# Processing Record 2 of Set 10 | uddevalla
# Processing Record 3 of Set 10 | cockburn town
# Processing Record 4 of Set 10 | abu samrah
# Processing Record 5 of Set 10 | atar
# Processing Record 6 of Set 10 | deogarh
# Processing Record 7 of Set 10 | xudat
# Processing Record 8 of Set 10 | nizhniy tsasuchey
# Processing Record 9 of Set 10 | pedernales
# Processing Record 10 of Set 10 | mount gambier
# Processing Record 11 of Set 10 | adrar
# Processing Record 12 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 13 of Set 10 | manakara
# Processing Record 14 of Set 10 | mortka
# Processing Record 15 of Set 10 | cangzhou
# Processing Record 16 of Set 10 | lubango
# Processing Record 17 of Set 10 | batagay
# Processing Record 18 of Set 10 | kavaratti
# Processing Record 19 of Set 10 | yar-sale
# Processing Record 20 of Set 10 | wanning
# Processing Record 21 of Set 10 | sabha
# Processing Record 22 of Set 10 | riohacha
# Processing Record 23 of Set 10 | asheville
# Processing Record 24 of Set 10 | lebu
# Processing Record 25 of Set 10 | tunceli
# Processing Record 26 of Set 10 | susehri
# Processing Record 27 of Set 10 | omsukchan
# Processing Record 28 of Set 10 | tchamba
# Processing Record 29 of Set 10 | lagoa
# Processing Record 30 of Set 10 | erenhot
# Processing Record 31 of Set 10 | northam
# Processing Record 32 of Set 10 | miri
# Processing Record 33 of Set 10 | pangkalanbuun
# Processing Record 34 of Set 10 | katherine
# Processing Record 35 of Set 10 | kemijarvi
# Processing Record 36 of Set 10 | lumsden
# Processing Record 37 of Set 10 | katima mulilo
# Processing Record 38 of Set 10 | nome
# Processing Record 39 of Set 10 | tuy hoa
# Processing Record 40 of Set 10 | bicester
# Processing Record 41 of Set 10 | pontes e lacerda
# Processing Record 42 of Set 10 | vestmannaeyjar
# Processing Record 43 of Set 10 | bowen
# Processing Record 44 of Set 10 | padang
# Processing Record 45 of Set 10 | waipawa
# Processing Record 46 of Set 10 | pevek
# Processing Record 47 of Set 10 | tiksi
# Processing Record 48 of Set 10 | hammerfest
# Processing Record 49 of Set 10 | aranos
# Processing Record 50 of Set 10 | smithers
# Processing Record 1 of Set 11 | iquitos
# Processing Record 2 of Set 11 | merano
# Processing Record 3 of Set 11 | balaipungut
# Processing Record 4 of Set 11 | santa vitoria do palmar
# Processing Record 5 of Set 11 | belyy yar
# Processing Record 6 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 11 | sungai padi
# Processing Record 8 of Set 11 | sunndalsora
# Processing Record 9 of Set 11 | youkounkoun
# Processing Record 10 of Set 11 | xinpu
# Processing Record 11 of Set 11 | pahrump
# Processing Record 12 of Set 11 | porto novo
# Processing Record 13 of Set 11 | bandarbeyla
# Processing Record 14 of Set 11 | arica
# Processing Record 15 of Set 11 | waddan
# Processing Record 16 of Set 11 | livingstone
# Processing Record 17 of Set 11 | sorland
# Processing Record 18 of Set 11 | yatou
# Processing Record 19 of Set 11 | creston
# Processing Record 20 of Set 11 | tshikapa
# Processing Record 21 of Set 11 | dennery
# Processing Record 22 of Set 11 | bembereke
# Processing Record 23 of Set 11 | miquelon
# Processing Record 24 of Set 11 | vestmanna
# Processing Record 25 of Set 11 | umm kaddadah
# Processing Record 26 of Set 11 | conakry
# Processing Record 27 of Set 11 | camana
# Processing Record 28 of Set 11 | kedrovyy
# Processing Record 29 of Set 11 | betsiamites
# Processing Record 30 of Set 11 | chara
# Processing Record 31 of Set 11 | raudeberg
# Processing Record 32 of Set 11 | delmas
# Processing Record 33 of Set 11 | santa cruz
# Processing Record 34 of Set 11 | kruisfontein
# Processing Record 35 of Set 11 | nurobod
# Processing Record 36 of Set 11 | bairiki
# Processing Record 37 of Set 11 | belaya gora
# Processing Record 38 of Set 11 | antalaha
# Processing Record 39 of Set 11 | ancud
# Processing Record 40 of Set 11 | nefteyugansk
# Processing Record 41 of Set 11 | rio gallegos
# Processing Record 42 of Set 11 | midyat
# Processing Record 43 of Set 11 | porto walter
# Processing Record 44 of Set 11 | ilo
# Processing Record 45 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 46 of Set 11 | port shepstone
# Processing Record 47 of Set 11 | sinnamary
# Processing Record 48 of Set 11 | mogadishu
# Processing Record 49 of Set 11 | paoua
# Processing Record 50 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 1 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 12 | ulladulla
# Processing Record 3 of Set 12 | oistins
# Processing Record 4 of Set 12 | loreto
# Processing Record 5 of Set 12 | ciucurova
# Processing Record 6 of Set 12 | kelebia
# Processing Record 7 of Set 12 | westport
# Processing Record 8 of Set 12 | tautira
# Processing Record 9 of Set 12 | kusa
# Processing Record 10 of Set 12 | tabuk
# Processing Record 11 of Set 12 | tocopilla
# Processing Record 12 of Set 12 | riyadh
# Processing Record 13 of Set 12 | benghazi
# Processing Record 14 of Set 12 | gasa
# Processing Record 15 of Set 12 | cabedelo
# Processing Record 16 of Set 12 | avera
# Processing Record 17 of Set 12 | yumen
# Processing Record 18 of Set 12 | harper
# Processing Record 19 of Set 12 | kampong cham
# Processing Record 20 of Set 12 | hami
# Processing Record 21 of Set 12 | morwell
# Processing Record 22 of Set 12 | ketchikan
# Processing Record 23 of Set 12 | grindavik
# Processing Record 24 of Set 12 | killybegs
# Processing Record 25 of Set 12 | koumac
# Processing Record 26 of Set 12 | yingcheng
# Processing Record 27 of Set 12 | oktyabrskiy
# Processing Record 28 of Set 12 | yarmouth
# Processing Record 29 of Set 12 | gondanglegi
# Processing Record 30 of Set 12 | udachnyy
# Processing Record 31 of Set 12 | new ulm
# Processing Record 32 of Set 12 | rocha
# Processing Record 33 of Set 12 | cobija
# Processing Record 34 of Set 12 | fallon
# Processing Record 35 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 12 | grand-santi
# Processing Record 37 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 38 of Set 12 | beipiao
# Processing Record 39 of Set 12 | fortuna
# Processing Record 40 of Set 12 | velyka bahachka
# Processing Record 41 of Set 12 | broome
# Processing Record 42 of Set 12 | severomuysk
# Processing Record 43 of Set 12 | valdepenas
# Processing Record 44 of Set 12 | rundu
# Processing Record 45 of Set 12 | egvekinot
# Processing Record 46 of Set 12 | poso
# Processing Record 47 of Set 12 | senges
# Processing Record 48 of Set 12 | kuandian
# Processing Record 49 of Set 12 | doctor juan leon mallorquin
# Processing Record 50 of Set 12 | matias romero
# Processing Record 1 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 13 | richards bay
# Processing Record 3 of Set 13 | vao
# Processing Record 4 of Set 13 | ranong
# Processing Record 5 of Set 13 | pangnirtung
# Processing Record 6 of Set 13 | hovd
# Processing Record 7 of Set 13 | gorom-gorom
# Processing Record 8 of Set 13 | huanuni
# Processing Record 9 of Set 13 | majengo
# Processing Record 10 of Set 13 | nazira
# Processing Record 11 of Set 13 | tessalit
# Processing Record 12 of Set 13 | ngunguru
# Processing Record 13 of Set 13 | kargil
# Processing Record 14 of Set 13 | vostok
# Processing Record 15 of Set 13 | camacha
# Processing Record 16 of Set 13 | whitehorse
# Processing Record 17 of Set 13 | barra
# Processing Record 18 of Set 13 | lynchburg
# Processing Record 19 of Set 13 | sobradinho
# Processing Record 20 of Set 13 | ust-maya
# Processing Record 21 of Set 13 | gafargaon
# Processing Record 22 of Set 13 | matamoros
# Processing Record 23 of Set 13 | the valley
# Processing Record 24 of Set 13 | geraldton
# Processing Record 25 of Set 13 | aqtobe
# Processing Record 26 of Set 13 | lakes entrance
# Processing Record 27 of Set 13 | rabapatona
# Processing Record 28 of Set 13 | itaunja
# Processing Record 29 of Set 13 | tucurui
# Processing Record 30 of Set 13 | rodrigues alves
# Processing Record 31 of Set 13 | abnub
# Processing Record 32 of Set 13 | iralaya
# Processing Record 33 of Set 13 | elko
# Processing Record 34 of Set 13 | killam
# Processing Record 35 of Set 13 | lodwar
# Processing Record 36 of Set 13 | bodoco
# City not found. Skipping...
# Processing Record 37 of Set 13 | isla mujeres
# Processing Record 38 of Set 13 | tarauaca
# Processing Record 39 of Set 13 | fort dodge
# Processing Record 40 of Set 13 | dauphin
# Processing Record 41 of Set 13 | skerries
# Processing Record 42 of Set 13 | pisco
# Processing Record 43 of Set 13 | borovoy
# Processing Record 44 of Set 13 | kudat
# Processing Record 45 of Set 13 | hobyo
# Processing Record 46 of Set 13 | innisfail
# Processing Record 47 of Set 13 | masallatah
# Processing Record 48 of Set 13 | eureka
# Processing Record 49 of Set 13 | mayor pablo lagerenza
# Processing Record 50 of Set 13 | svetlogorsk
# Processing Record 1 of Set 14 | vanavara
# Processing Record 2 of Set 14 | gushikawa
# Processing Record 3 of Set 14 | kamsack
# Processing Record 4 of Set 14 | nova olinda do norte
# Processing Record 5 of Set 14 | walvis bay
# Processing Record 6 of Set 14 | sanchor
# Processing Record 7 of Set 14 | blagoyevo
# Processing Record 8 of Set 14 | ruse
# Processing Record 9 of Set 14 | nicoya
# Processing Record 10 of Set 14 | cholan
# City not found. Skipping...
# Processing Record 11 of Set 14 | bafra
# Processing Record 12 of Set 14 | khorixas
# Processing Record 13 of Set 14 | krasnoselkup
# Processing Record 14 of Set 14 | churapcha
# Processing Record 15 of Set 14 | kichera
# Processing Record 16 of Set 14 | malindi
# Processing Record 17 of Set 14 | nidadavole
# Processing Record 18 of Set 14 | martapura
# Processing Record 19 of Set 14 | kismayo
# Processing Record 20 of Set 14 | manzanillo
# Processing Record 21 of Set 14 | saint-pierre
# Processing Record 22 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 14 | tucuman
# Processing Record 24 of Set 14 | asfi
# Processing Record 25 of Set 14 | kasongo-lunda
# Processing Record 26 of Set 14 | akdepe
# Processing Record 27 of Set 14 | margate
# Processing Record 28 of Set 14 | boyolangu
# Processing Record 29 of Set 14 | kyzyl-suu
# Processing Record 30 of Set 14 | ostersund
# Processing Record 31 of Set 14 | curillo
# Processing Record 32 of Set 14 | morondava
# Processing Record 33 of Set 14 | bull savanna
# Processing Record 34 of Set 14 | urumqi
# Processing Record 35 of Set 14 | ekhabi
# Processing Record 36 of Set 14 | malumfashi
# Processing Record 37 of Set 14 | sulechow
# Processing Record 38 of Set 14 | otane
# Processing Record 39 of Set 14 | calabozo
# Processing Record 40 of Set 14 | epe
# Processing Record 41 of Set 14 | roma
# Processing Record 42 of Set 14 | san pedro de macoris
# Processing Record 43 of Set 14 | uray
# Processing Record 44 of Set 14 | binalbagan
# Processing Record 45 of Set 14 | vicuna
# Processing Record 46 of Set 14 | san policarpo
# Processing Record 47 of Set 14 | kilindoni
# Processing Record 48 of Set 14 | phalodi
# Processing Record 49 of Set 14 | san pedro
# Processing Record 50 of Set 14 | aykhal
# Processing Record 1 of Set 15 | dublin
# Processing Record 2 of Set 15 | bloemfontein
# Processing Record 3 of Set 15 | djibo
# Processing Record 4 of Set 15 | arkadak
# Processing Record 5 of Set 15 | lima
# Processing Record 6 of Set 15 | mitu
# Processing Record 7 of Set 15 | rawson
# Processing Record 8 of Set 15 | taveta
# Processing Record 9 of Set 15 | mangrol
# Processing Record 10 of Set 15 | nagorsk
# Processing Record 11 of Set 15 | mamu kanjan
# Processing Record 12 of Set 15 | taloqan
# Processing Record 13 of Set 15 | luangwa
# Processing Record 14 of Set 15 | podor
# Processing Record 15 of Set 15 | jumla
# Processing Record 16 of Set 15 | kim
# Processing Record 17 of Set 15 | mount pleasant
# Processing Record 18 of Set 15 | nuuk
# Processing Record 19 of Set 15 | broken hill
# Processing Record 20 of Set 15 | cayenne
# Processing Record 21 of Set 15 | sidi qasim
# City not found. Skipping...
# Processing Record 22 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 15 | santa fe
# Processing Record 24 of Set 15 | saurimo
# Processing Record 25 of Set 15 | mizque
# Processing Record 26 of Set 15 | roald
# Processing Record 27 of Set 15 | benjamin constant
# Processing Record 28 of Set 15 | mokhsogollokh
# Processing Record 29 of Set 15 | makakilo city
# Processing Record 30 of Set 15 | les cayes
# Processing Record 31 of Set 15 | atambua
# Processing Record 32 of Set 15 | kostek
# Processing Record 33 of Set 15 | alofi
# Processing Record 34 of Set 15 | charlestown
# Processing Record 35 of Set 15 | pedro carbo
# Processing Record 36 of Set 15 | mayumba
# Processing Record 37 of Set 15 | san jeronimo
# Processing Record 38 of Set 15 | palmer
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 683

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity Current Discription  \
# 0          Atuona  -9.8000 -139.0333     76.39        79          light rain
# 1       Upernavik  72.7868  -56.1549     17.11        81       broken clouds
# 2           Vaini -21.2000 -175.2000     75.36        88       broken clouds
# 3          Hasaki  35.7333  140.8333     54.00        82     overcast clouds
# 4          Hobart -42.8794  147.3294     47.26        69          few clouds
# 5     Tuktoyaktuk  69.4541 -133.0374     42.22        75     overcast clouds
# 6         College  64.8569 -147.8028     44.92        88          light rain
# 7    Komsomolskiy  40.4272   71.7189     54.32        50           clear sky
# 8  Port Elizabeth -33.9180   25.5701     63.10        92           clear sky
# 9          Barrow  71.2906 -156.7887     35.62        69          few clouds
#
#    Cloudiness  Wind Speed Country
# 0          27       19.93      PF
# 1          68        3.83      GL
# 2          75       10.36      TO
# 3         100       11.48      JP
# 4          20       10.36      AU
# 5         100       18.79      CA
# 6         100       11.50      US
# 7           6        6.91      UZ
# 8           4        7.00      ZA
# 9          20       31.07      US

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Current Discription',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reorder = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Discription']

# Recreate the DataFrame by using the new column order
ordered_city_data_df = city_data_df[reorder]
ordered_city_data_df = ordered_city_data_df.rename(columns={'Current Discription':"Current Description"})

# Display sample data
ordered_city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Atuona      PF  -9.8000 -139.0333     76.39        79          27
# 1       Upernavik      GL  72.7868  -56.1549     17.11        81          68
# 2           Vaini      TO -21.2000 -175.2000     75.36        88          75
# 3          Hasaki      JP  35.7333  140.8333     54.00        82         100
# 4          Hobart      AU -42.8794  147.3294     47.26        69          20
# 5     Tuktoyaktuk      CA  69.4541 -133.0374     42.22        75         100
# 6         College      US  64.8569 -147.8028     44.92        88         100
# 7    Komsomolskiy      UZ  40.4272   71.7189     54.32        50           6
# 8  Port Elizabeth      ZA -33.9180   25.5701     63.10        92           4
# 9          Barrow      US  71.2906 -156.7887     35.62        69          20
#
#    Wind Speed Current Description
# 0       19.93          light rain
# 1        3.83       broken clouds
# 2       10.36       broken clouds
# 3       11.48     overcast clouds
# 4       10.36          few clouds
# 5       18.79     overcast clouds
# 6       11.50          light rain
# 7        6.91           clear sky
# 8        7.00           clear sky
# 9       31.07          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
ordered_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
ordered_city_data_df.to_csv(output_data_file)
